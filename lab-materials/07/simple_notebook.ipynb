# %% [markdown]
# # ![image.png](attachment:6419f08b-b1f0-4dfc-ab60-a5579b21330d.png) Welcome to the Sweden challenge ![image.png](attachment:400baadc-2d38-42e0-a547-1ccfc0246459.png)

# %% [markdown]
# In this challenge we will try to save Swedens economy by analyzing and improving OMEA's pricing model.
# To do that, let's start by taking a look at the dataset.

# %%
import pandas as pd
df = pd.read_csv("data/clean_OMEA_dataset.csv")
df.head()
# Out:
#                     name       category   price  old_price  sellable_online  \
# 0               FREKVENS  Bar furniture   265.0      265.0             True
# 1              NORDVIKEN  Bar furniture   995.0      995.0            False
# 2  NORDVIKEN / NORDVIKEN  Bar furniture  2095.0     2095.0            False
# 3                   STIG  Bar furniture    69.0       69.0             True
# 4                NORBERG  Bar furniture   225.0      225.0             True
#
#   other_colors                                  short_description      depth  \
# 0           No           Bar table, in/outdoor,          51x51 cm  46.925926
# 1           No                      Bar table,          140x80 cm  46.925926
# 2           No                         Bar table and 4 bar stools  46.925926
# 3          Yes            Bar stool with backrest,          74 cm  50.000000
# 4           No          Wall-mounted drop-leaf table,         ...  60.000000
#
#        height      width  discounted  width_d  height_d  depth_d  \
# 0   99.000000  51.000000           0        1         1        0
# 1  105.000000  80.000000           0        1         1        0
# 2   97.571429  52.945946           0        0         0        0
# 3  100.000000  60.000000           0        1         1        1
# 4   43.000000  74.000000           0        1         1        1
#
#    discount_amount      size
# 0              0.0    5049.0
# 1              0.0    8400.0
# 2              0.0       1.0
# 3              0.0  300000.0
# 4              0.0  190920.0

# %% [markdown]
# ### These are the features we have available in the dataset
# **name** - (String) The name of the furniture.
# **category** - (String) What type of furniture it is. This will be converted to multiple columns with 1 or 0 if it's that category or not (to make it easy for the AI to read).
# **price** - (Float) The current price of the product.
# **old_price** - (Float) A previous price of the product, same as the current price in many cases.
# **sellable_online** - (Bool) If the item is sellable online, this will be True.
# **other_colors** - (Bool) If the item has other color variants, this will be True.
# **width** - (Float) The width of the item, if applicable.
# **depth** - (Float) The depth of the item, if applicable.
# **height** - (Float) The height of the item, if applicable.
# **discounted** - (Int) Takes 1 if the item is discounted, 0 otherwise.
# **width_d** - (Int) Takes 1 if it had a weight or 0 if it was NaN and was assigned a value through interpolation.
# **height_d** -  (Int) Takes 1 if it had a height or 0 if it was NaN and was assigned a value through interpolation.
# **depth_d** -  (Int) Takes 1 if it had a depth or 0 if it was NaN and was assigned a value through interpolation.
# **discount_amount** - (Float) How much to discount the item with.
# **size** - (Float) The total size of the item, 1 in case none of the shapes were given.

# %% [markdown]
# We see a gooda mount of features (columns) in the dataset with verying values.
# The first thing we need to do is to select which of these features will be used to train our model.

# %% [markdown]
# ## Time to pick your features!
# Choose the features you want to include in your training.
# We need to choose input features as well as an output feature (we can't use Category as output).
#
# NOTE: You are not allowed to include both *discount_amount* and *old_price* in INPUT_FEATURES.
# Quiz: Why would this be a pointless excerice?

# %% [markdown]
# Don't forget to set your model name to something interesting!

# %%
MODEL_NAME = "new_model"

INPUT_FEATURES = [
    # "name", # The model can't handle freeform names
    "category",
    # "price",
    # "old_price",
    "sellable_online",
    "other_colors",
    # "short_description", # The model can't handle freeform descriptions
    "width",
    "height",
    "depth",
    "width_d",
    "height_d",
    "depth_d",
    "discounted",
    "discount_amount",
    "size"
]
PREDICT_TARGET = "price"

# %% [markdown]
# The last thing we need to do is select how our training/testing data split is going to look like.

# %%
def split_function(df):
    from sklearn.model_selection import train_test_split
    return train_test_split(df, shuffle=True, test_size=0.3, random_state=42)

# %% [markdown]
# ## Let's train our model!
# Since this challenge is about looking at features and data, we don't worry about how exactly the model looks like, so we will just run a train_model function and be happy 🤷‍♀️

# %%
from support_functions.model_training import train_model
test = train_model(df, INPUT_FEATURES, PREDICT_TARGET, split_function, MODEL_NAME)
# Out:
# 2024-12-20 17:20:02.304202: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-20 17:20:02.318183: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1734715202.333047  106073 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1734715202.337504  106073 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-20 17:20:02.352888: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-20 17:20:03.842610: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step - loss: 0.0179 - mean_squared_error: 0.0179
# Epoch 2/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 3/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 807us/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 4/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 764us/step - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 5/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 787us/step - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 6/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 763us/step - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 7/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 787us/step - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 8/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 9/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 10/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 771us/step - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 11/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 764us/step - loss: 0.0083 - mean_squared_error: 0.0083
# Epoch 12/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - loss: 0.0082 - mean_squared_error: 0.0082
# Epoch 13/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 785us/step - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 14/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 759us/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 15/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step - loss: 0.0083 - mean_squared_error: 0.0083
# Epoch 16/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 794us/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 17/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 18/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 19/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step - loss: 0.0078 - mean_squared_error: 0.0078
# Epoch 20/20
# 1289/1289 ━━━━━━━━━━━━━━━━━━━━ 1s 767us/step - loss: 0.0079 - mean_squared_error: 0.0079

# %% [markdown]
# Great!
# We now have a model and some artifacts. They are saved in the folder with the same name as you gave variable **MODEL_NAME** if you want to take a look.

# %% [markdown]
# Now let's do the fun part and *Evaluate* the model.
# We will do a few evaluations. The first one will show us these interesting things:
# - **The Mean Square Error** - this is how far away we are from the correct value on average.
# - **The worst prediction** - this will tell us what our worst prediction was and how far away it was.
# - **A list of all prices <0** - we probably want as few in this list as possible, as giving furniture away for less than free is rarely a substainable business model.

# %%
from support_functions.evaluate_model import model_evaluation
worst_df, below_zero_df = model_evaluation(MODEL_NAME, PREDICT_TARGET)
# Out:
#  Evaluate the new model against the test set:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# The model has an MSE of 64.4352990500629 (0.006411531940102577 when scaled) on the test data.

# %%
worst_df
# Out:
#     prediction  target        error
# 0  5937.039062   960.0  4977.039062

# %%
below_zero_df
# Out:
#            price  sellable_online  other_colors      depth      height  \
# 3440   -0.820586                1             0  37.150376   99.664062
# 402   -68.133453                1             0  51.000000   15.000000
# 1064  -67.510490                1             0  37.493671  113.408696
# 976   -27.552547                1             1  24.000000  113.408696
# 511   -31.174379                1             0  36.922737  131.097285
# 52    -65.515106                0             0  81.734940   82.847134
# 3379   -0.820586                1             0  37.150376   99.664062
# 670   -45.419262                1             1  36.922737  131.097285
# 965   -67.510490                1             0  37.493671  113.408696
# 3286  -42.947117                1             0  42.000000   53.000000
# 1055 -394.507355                1             0  38.000000   10.000000
# 1912  -19.017982                1             0  43.090909   84.821429
# 1032  -67.510490                1             0  37.493671  113.408696
# 139   -17.247618                1             0  81.734940   82.847134
# 978    -0.897403                1             0  30.000000  113.408696
# 1116 -110.592094                1             0  38.000000   76.837931
# 1044 -103.880585                1             1  37.493671  113.408696
# 3426   -0.820586                1             0  37.150376   99.664062
# 3376   -0.820586                1             0  37.150376   99.664062
# 764    -9.049166                1             0  36.922737  131.097285
# 266  -158.821182                1             0  12.000000   35.000000
# 3392   -0.820586                1             0  37.150376   99.664062
# 432    -8.755462                1             0  36.922737  131.097285
# 1644  -64.728798                1             1  47.157025   78.487805
# 3446 -164.232224                0             0  18.000000   99.664062
# 430   -83.673660                1             0  51.000000   15.000000
# 657    -8.755462                1             0  36.922737  131.097285
# 88    -54.172855                1             0  81.734940   82.847134
# 3436   -0.820586                1             0  37.150376   99.664062
# 505   -45.419262                1             1  36.922737  131.097285
# 1027  -67.510490                1             0  37.493671  113.408696
# 949  -103.880585                1             1  37.493671  113.408696
# 612  -112.719559                0             0  18.000000  131.097285
# 1902  -51.258228                1             0  46.000000   84.821429
# 912    -7.888912                1             0  27.000000  113.408696
# 679    -9.049166                1             0  36.922737  131.097285
# 3409   -0.820586                1             0  37.150376   99.664062
# 678    -9.049166                1             0  36.922737  131.097285
# 422   -26.759531                1             0  51.000000  104.000000
# 532  -308.935852                1             0  38.000000   10.000000
# 162   -17.247618                1             0  81.734940   82.847134
# 611    -9.049166                1             0  36.922737  131.097285
# 3374   -0.820586                1             0  37.150376   99.664062
# 3424  -37.190823                1             1  37.150376   99.664062
# 3324   -0.820586                1             0  37.150376   99.664062
# 59    -11.972504                1             0  81.734940   82.847134
# 1835  -55.916519                1             0  45.000000   77.000000
# 533    -9.049166                1             0  36.922737  131.097285
# 942   -12.549917                1             0  25.000000  113.408696
# 350   -31.222496                1             1  60.000000   14.000000
# 3410  -22.740191                1             0  37.150376   10.000000
#
#            width  discounted  width_d  height_d  depth_d  discount_amount  \
# 3440  132.285714           0        0         0        0              0.0
# 402    50.000000           1        1         1        1              2.0
# 1064   98.750000           0        0         0        0              0.0
# 976    98.750000           0        0         0        1              0.0
# 511     8.000000           0        1         0        0              0.0
# 52     91.000000           0        1         0        0              0.0
# 3379  132.285714           0        0         0        0              0.0
# 670   106.563008           0        0         0        0              0.0
# 965    98.750000           0        0         0        0              0.0
# 3286  120.000000           1        1         1        1             15.0
# 1055   98.750000           1        0         1        1             19.5
# 1912   28.000000           0        1         0        0              0.0
# 1032   98.750000           0        0         0        0              0.0
# 139    90.000000           0        1         0        0              0.0
# 978    98.750000           0        0         0        1              0.0
# 1116   66.156812           1        0         0        1              5.0
# 1044   98.750000           0        0         0        0              0.0
# 3426  132.285714           0        0         0        0              0.0
# 3376  132.285714           0        0         0        0              0.0
# 764   106.563008           0        0         0        0              0.0
# 266    33.000000           1        1         1        1             20.0
# 3392  132.285714           0        0         0        0              0.0
# 432    25.000000           0        1         0        0              0.0
# 1644   38.000000           0        1         0        0              0.0
# 3446   24.000000           0        1         0        1              0.0
# 430    25.000000           1        1         1        1              2.0
# 657    25.000000           0        1         0        0              0.0
# 88     62.000000           0        1         0        0              0.0
# 3436  132.285714           0        0         0        0              0.0
# 505   106.563008           0        0         0        0              0.0
# 1027   98.750000           0        0         0        0              0.0
# 949    98.750000           0        0         0        0              0.0
# 612    24.000000           0        1         0        1              0.0
# 1902   79.000000           1        1         0        1            199.0
# 912    98.750000           0        0         0        1              0.0
# 679   106.563008           0        0         0        0              0.0
# 3409  132.285714           0        0         0        0              0.0
# 678   106.563008           0        0         0        0              0.0
# 422    50.000000           1        1         1        1              7.0
# 532   106.563008           1        0         1        1             19.5
# 162    90.000000           0        1         0        0              0.0
# 611   106.563008           0        0         0        0              0.0
# 3374  132.285714           0        0         0        0              0.0
# 3424  132.285714           0        0         0        0              0.0
# 3324  132.285714           0        0         0        0              0.0
# 59     94.000000           0        1         0        0              0.0
# 1835   41.000000           1        1         1        1             55.0
# 533   106.563008           0        0         0        0              0.0
# 942    98.750000           0        0         0        1              0.0
# 350    38.000000           1        1         1        1             12.0
# 3410  132.285714           0        0         1        0              0.0
#
#           size                          category
# 3440       1.0              TV & media furniture
# 402    38250.0        Bookcases & shelving units
# 1064       1.0              Cabinets & cupboards
# 976       24.0              Cabinets & cupboards
# 511        8.0        Bookcases & shelving units
# 52        91.0                              Beds
# 3379       1.0              TV & media furniture
# 670        1.0        Bookcases & shelving units
# 965        1.0              Cabinets & cupboards
# 3286  267120.0              TV & media furniture
# 1055     380.0              Cabinets & cupboards
# 1912      28.0                 Nursery furniture
# 1032       1.0              Cabinets & cupboards
# 139       90.0                              Beds
# 978       30.0              Cabinets & cupboards
# 1116      38.0                            Chairs
# 1044       1.0              Cabinets & cupboards
# 3426       1.0              TV & media furniture
# 3376       1.0              TV & media furniture
# 764        1.0        Bookcases & shelving units
# 266    13860.0        Bookcases & shelving units
# 3392       1.0              TV & media furniture
# 432       25.0        Bookcases & shelving units
# 1644      38.0  Chests of drawers & drawer units
# 3446     432.0              TV & media furniture
# 430    19125.0        Bookcases & shelving units
# 657       25.0        Bookcases & shelving units
# 88        62.0                              Beds
# 3436       1.0              TV & media furniture
# 505        1.0        Bookcases & shelving units
# 1027       1.0              Cabinets & cupboards
# 949        1.0              Cabinets & cupboards
# 612      432.0        Bookcases & shelving units
# 1902    3634.0                 Nursery furniture
# 912       27.0              Cabinets & cupboards
# 679        1.0        Bookcases & shelving units
# 3409       1.0              TV & media furniture
# 678        1.0        Bookcases & shelving units
# 422   265200.0        Bookcases & shelving units
# 532      380.0        Bookcases & shelving units
# 162       90.0                              Beds
# 611        1.0        Bookcases & shelving units
# 3374       1.0              TV & media furniture
# 3424       1.0              TV & media furniture
# 3324       1.0              TV & media furniture
# 59        94.0                              Beds
# 1835  142065.0              Children's furniture
# 533        1.0        Bookcases & shelving units
# 942       25.0              Cabinets & cupboards
# 350    31920.0        Bookcases & shelving units
# 3410      10.0              TV & media furniture

# %% [markdown]
# I think this video is apt for the result we just saw:

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('NlWCLw75XnE', width=800, height=300)

# %% [markdown]
# Now that we have some insight into that the model *does* go wrong, let's see if we can get an understanding of *what's* going wrong.
# For that, we will use TrustyAI's **Counterfactual** and **SHAP** 🧙‍♂️

# %% [markdown]
# ## Counterfactual Analysis
# Counterfactual analysis will tell us what values we would have to input to get a different, desired, answer than the one we got.
# Here we will use it to see what we would have to change in one of our results for the value to be possitive.
#
# We also need to choose a **DATAPOINT** to analyze. We can start with datapoint number 1055, but you can pick any from the above list of datapoints which return value < 0.

# %%
DATAPOINT=1055

# %%
from support_functions.counterfactual import counterfactual
explanation = counterfactual(MODEL_NAME, PREDICT_TARGET, DATAPOINT)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# -394.50735
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -394.50735
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -107.95532
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -101.08504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# -382.30573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1198.5352
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# -337.55756
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 631.56
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -938.94366
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -347.66528
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -382.30573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -190.55511
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -404.88013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -623.3294
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -273.4152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -304.41864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -251.02597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -213.333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -337.1055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -213.333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -107.95532
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -398.06195
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -334.03595
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -407.17963
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -262.0024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -273.4152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -405.06332
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 870.221
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -188.9815
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# -391.1854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1912.6741
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -478.39847
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -401.7212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -305.99182
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -304.41864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 100.57457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -101.08504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -273.4152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -879.9055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -354.94894
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 650.8166
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -811.4091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# -382.30573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -453.54526
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -273.4152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -339.28864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 119.791725
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# -337.55756
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 415.28357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# -280.40927
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 119.791725

# %% [markdown]
# We can now see the results of our counterfacutal analysis!
# In the first table it will show us how much it needed to change a feature to get the value to become possitive.
# It's noteworthy that it tries to do the smallest change possible.

# %%
explanation.as_dataframe()
# Out:
#                                          features  proposed  original  \
# 0                                 sellable_online  1.000000  1.000000
# 1                                    other_colors  0.000000  0.000000
# 2                                           depth  0.144531  0.144531
# 3                                          height  0.012876  0.012876
# 4                                           width  0.233294  0.233294
# 5                                      discounted  1.000000  1.000000
# 6                                         width_d  0.000000  0.000000
# 7                                        height_d  1.000000  1.000000
# 8                                         depth_d  1.000000  1.000000
# 9                                 discount_amount  0.273109  0.009765
# 10                                           size  0.000028  0.000028
# 11                         category_Bar furniture  0.000000  0.000000
# 12                                  category_Beds  0.000000  0.000000
# 13            category_Bookcases & shelving units  0.000000  0.000000
# 14                  category_Cabinets & cupboards  1.000000  1.000000
# 15                        category_Café furniture  0.000000  0.000000
# 16                                category_Chairs  0.000000  0.000000
# 17      category_Chests of drawers & drawer units  0.000000  0.000000
# 18                  category_Children's furniture  0.000000  0.000000
# 19                     category_Nursery furniture  0.000000  0.000000
# 20                     category_Outdoor furniture  0.000000  0.000000
# 21                         category_Room dividers  0.000000  0.000000
# 22  category_Sideboards, buffets & console tables  0.000000  0.000000
# 23                     category_Sofas & armchairs  0.000000  0.000000
# 24                  category_TV & media furniture  0.000000  0.000000
# 25                        category_Tables & desks  0.000000  0.000000
# 26                              category_Trolleys  0.000000  0.000000
# 27                             category_Wardrobes  0.000000  0.000000
#
#     constrained  difference
# 0         False    0.000000
# 1         False    0.000000
# 2         False    0.000000
# 3         False    0.000000
# 4         False    0.000000
# 5         False    0.000000
# 6         False    0.000000
# 7         False    0.000000
# 8         False    0.000000
# 9         False    0.263344
# 10        False    0.000000
# 11        False    0.000000
# 12        False    0.000000
# 13        False    0.000000
# 14        False    0.000000
# 15        False    0.000000
# 16        False    0.000000
# 17        False    0.000000
# 18        False    0.000000
# 19        False    0.000000
# 20        False    0.000000
# 21        False    0.000000
# 22        False    0.000000
# 23        False    0.000000
# 24        False    0.000000
# 25        False    0.000000
# 26        False    0.000000
# 27        False    0.000000

# %% [markdown]
# Here is a small version of that big table (for those like me who don't want to scoure through it).
# This small version only shows the feature that needed a change.

# %%
df = explanation.as_dataframe()
df[df.difference != 0.0]
# Out:
#           features  proposed  original  constrained  difference
# 9  discount_amount  0.273109  0.009765        False    0.263344

# %% [markdown]
# Finally, we can see the exact same thing - the original value(s) vs what they need to be to make our prediction possitive.
# But, this time it's visualized in a nice graph! :D

# %%
if not df[df.difference != 0.0].empty:
    explanation.plot()
else:
    print(f"We did not manage to make '{PREDICT_TARGET}' larger than '{0}'")

# %% [markdown]
# ## SHAP
